# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_moons
X,target = make_moons(n_samples=100, noise=0.24)

# %%
df = pd.DataFrame(X)
df = pd.concat([pd.Series(1,index = df.index,name = "00"),df],axis = 1)

# %%
df.head()
# Out:
#    00         0         1
# 0   1  0.162633  0.376339
# 1   1 -0.457045  1.042485
# 2   1  0.222668 -0.248287
# 3   1  1.180505 -0.516392
# 4   1  0.263442 -0.502178

# %%
y = pd.Series(target)

# %%
plt.scatter(X[:,0],X[:,1],c = y.map({1:'red',0:'blue'}))

# %%
def h_x(X,theta):
    z = X@theta
    return 1/(1+np.exp(-(z)))+0.000001

# %%
def cost_func(X,y,theta):
    y1 = h_x(X,theta)
    return -(1/X.shape[0])*np.sum(y*np.log(y1)+(1-y)*np.log(1-y1))

# %%
def train(X,Y,theta,alpha,epochs):
    m = X.shape[0]
    loss_matrix = []
    for epoch in range(epochs):
        h = h_x(X,theta)
        step = (1/m)*(X.T@(h-Y))
        theta = theta - (alpha*step)
        loss_matrix.append(cost_func(X,Y,theta))
    return loss_matrix,theta

# %%
theta = np.zeros((df.shape[1],1))
losses,the = train(df.values,target.reshape(-1,1),theta,0.1,500)

# %%
plt.plot(losses)

# %%
predicted_labels = h_x(df,the).values
for i in range(predicted_labels.shape[0]):
    if predicted_labels[i][0] >0.5:
        predicted_labels[i][0] = 1
    else:
        predicted_labels[i][0] = 0
predicted_labels =  predicted_labels.reshape(-1,)

# %%
plt.scatter(X[:,0],X[:,1],c = pd.Series(predicted_labels).map({1:'red',0:'blue'}))

# %% [markdown]
# ## Making a desition Boundary

# %%
W = the.reshape(-1,)
b = W[0]
W = W[1:]
print("Bias : {}\nWeights : {}".format(b,W))

# %% [raw]
# Converting the hypothesis --> Y(predicted) = B + x1*W1 + x2*w2 ____(eq.1)
# Y(Pred) will be negative if sigma(yPred) predict < 0.5 and vice versa
# But here We put the Y(predicted) = 0  in (eq.1) so we can move to middel of prediction
# Now, we have a equation like [ 0 = B + x1*W1 + x2*W2 ] .....
# ... can be modified as
# [ -x2*W2 = B + x1*W1 ]
# [  x2  = -(B + x1*W1)/W2 ]
#
# here, we can see that we can predict x2(feature 2) with the help of x1 (Feature 1)
# And this feature is mapeed to the axis where the decision boundry predicts 0 means middle
# After that we can map this with respect to x1(feature 1) and can see the line ...

# %%
x2 = -(b + (W[0]/1)*df[0])/(W[1]/1)

# %%
plt.scatter(df[0],df[1],c = pd.Series(predicted_labels).map({1:'red',0:'blue'}))
plt.plot(df[0],x2,c = "green")
plt.title("On Predicted points")
# Out:
# Text(0.5, 1.0, 'On Predicted points')

# %%
plt.scatter(X[:,0],X[:,1],c = y.map({1:'red',0:'blue'}))
plt.plot(df[0],x2,c = "green")
plt.title('Actual labelling')
# Out:
# Text(0.5, 1.0, 'Actual labelling')
